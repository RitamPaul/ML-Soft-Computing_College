# %% [markdown]
# Take the heart disease dataset & calculate the mean, variance, kurtosis and skewness. Plot the graph of mean, variance, kurtosis and skewness for the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import kurtosis, skew
import urllib.request

# Download dataset
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data'
urllib.request.urlretrieve(url, 'heart_disease.csv')

# Load and clean dataset
col_names = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "target"]
df = pd.read_csv('heart_disease.csv', names=col_names, na_values='?').dropna()

# Calculate statistics
numeric_df = df.select_dtypes(include=[float, int])
stats = pd.DataFrame({
    'Mean': numeric_df.mean(),
    'Variance': numeric_df.var(),
    'Kurtosis': numeric_df.apply(lambda x: kurtosis(x, fisher=True)),
    'Skewness': numeric_df.apply(lambda x: skew(x))
})

# Plot statistics
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
for ax, stat in zip(axs.flatten(), stats.columns):
    ax.bar(stats.index, stats[stat])
    ax.set_title(stat)
    ax.set_xticklabels(stats.index, rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-2-7bb0d27afd05>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(stats.index, rotation=90)
# <ipython-input-2-7bb0d27afd05>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(stats.index, rotation=90)
# <ipython-input-2-7bb0d27afd05>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(stats.index, rotation=90)
# <ipython-input-2-7bb0d27afd05>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(stats.index, rotation=90)
